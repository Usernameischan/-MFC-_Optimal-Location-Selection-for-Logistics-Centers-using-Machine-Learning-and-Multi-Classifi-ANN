# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
mpl.rcParams["axes.unicode_minus"] = False
from sklearn.metrics import classification_report
import missingno as msno
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 데이터

# %%
con = pd.read_excel("eda 분석.xlsx")
con.head()
# Out:
#           GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0  현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1      선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2    현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3               서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4        ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
#
#      ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  POP1000  \
# 0   8280000     8.970251    13.202286     11.678968     166    4465    15660
# 1  18850000     9.568763    12.593357     11.494239     349    7404    25467
# 2  15050000     9.713120    12.454393     11.199948     251    7069    26924
# 3  10330000     9.772973    12.403577     11.855362     102    8374    30288
# 4  13300000    11.006969    11.272070     10.639303     186    5401    27394
#
#    SCHOOL  APART  MARKET
# 0       5      1      58
# 1       9      2       6
# 2       9      1      22
# 3       5      2       4
# 4       9      6      20

# %%
con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469 entries, 0 to 468
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GAS_STATION   469 non-null    object
#  1   DISTRICT      469 non-null    object
#  2   DONG          469 non-null    object
#  3   LATITUDE      469 non-null    float64
#  4   LONGITUDE     469 non-null    float64
#  5   AREA          469 non-null    float64
#  6   ESTATE        469 non-null    int64
#  7   DIST_EASTDC   469 non-null    float64
#  8   DIST_WESTDC   469 non-null    float64
#  9   DIST_KOREADC  469 non-null    float64
#  10  POP100        469 non-null    int64
#  11  POP500        469 non-null    int64
#  12  POP1000       469 non-null    int64
#  13  SCHOOL        469 non-null    int64
#  14  APART         469 non-null    int64
#  15  MARKET        469 non-null    int64
# dtypes: float64(6), int64(7), object(3)
# memory usage: 58.8+ KB

# %% [markdown]
# 수치형 데이터로만 EDA를 진행한다.

# %%
import sys
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]'

# %%
data = con.loc[:, ['AREA', 'ESTATE', 'DIST_EASTDC', 'DIST_WESTDC', 'DIST_KOREADC','POP1000','SCHOOL','APART','MARKET']]
data
# Out:
#        AREA    ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP1000  \
# 0     245.0   8280000     8.970251    13.202286     11.678968    15660
# 1     711.0  18850000     9.568763    12.593357     11.494239    25467
# 2     700.0  15050000     9.713120    12.454393     11.199948    26924
# 3    1010.0  10330000     9.772973    12.403577     11.855362    30288
# 4     519.0  13300000    11.006969    11.272070     10.639303    27394
# ..      ...       ...          ...          ...           ...      ...
# 464  1366.0   4205000    12.288585    26.954691     25.294460    12421
# 465  1640.7   4395000    11.849594    26.639204     24.849744    18592
# 466   271.0   5671000    10.807711    25.756175     23.746627    28101
# 467   815.0   5380000    11.191130    26.466958     24.267332    30149
# 468   591.0   4816000     9.420522    25.024822     22.399970    34359
#
#      SCHOOL  APART  MARKET
# 0         5      1      58
# 1         9      2       6
# 2         9      1      22
# 3         5      2       4
# 4         9      6      20
# ..      ...    ...     ...
# 464       4      1       0
# 465       4      1       0
# 466       0      0       4
# 467       3      1       2
# 468       4      3       4
#
# [469 rows x 9 columns]

# %% [markdown]
# ## 데이터 탐색

# %% [markdown]
# ### 데이터 요약

# %%
info_data = (pd.DataFrame({"Features" : data.columns, "Non-Null Count" : data.count(), 
                               "Null Count" : data.isnull().sum(), "Datatypes" : data.dtypes}).sort_values(by = "Datatypes")\
                              .reset_index(drop = True))
stats_data = data.describe(include = "all").T.reset_index()
total = pd.merge(info_data, stats_data, right_on = "index", left_on = "Features", how = "inner")\
                .drop(columns = ["index", "count"]).round(0)
total = total.fillna(0)
total.style.bar(subset = ["mean", "std", "min", "25%", "50%", "75%", "max"], axis = 1)\
    .format({'mean' : "{:20,.0f}", 'std' : "{:20,.0f}", 'min' : "{:20,.0f}", '25%' : "{:20,.0f}", '50%' : "{:20,.0f}",
             '75%' : "{:20,.0f}", 'max' : "{:20,.0f}"})\
    .set_properties(**{"background-color" : "#f9f9f9", "color" : "black", "border-color" : "white"}).hide_index()
# Out:
# <style type="text/css">
# #T_940f9_row0_col0, #T_940f9_row0_col1, #T_940f9_row0_col2, #T_940f9_row0_col3, #T_940f9_row1_col0, #T_940f9_row1_col1, #T_940f9_row1_col2, #T_940f9_row1_col3, #T_940f9_row2_col0, #T_940f9_row2_col1, #T_940f9_row2_col2, #T_940f9_row2_col3, #T_940f9_row3_col0, #T_940f9_row3_col1, #T_940f9_row3_col2, #T_940f9_row3_col3, #T_940f9_row4_col0, #T_940f9_row4_col1, #T_940f9_row4_col2, #T_940f9_row4_col3, #T_940f9_row5_col0, #T_940f9_row5_col1, #T_940f9_row5_col2, #T_940f9_row5_col3, #T_940f9_row6_col0, #T_940f9_row6_col1, #T_940f9_row6_col2, #T_940f9_row6_col3, #T_940f9_row7_col0, #T_940f9_row7_col1, #T_940f9_row7_col2, #T_940f9_row7_col3, #T_940f9_row8_col0, #T_940f9_row8_col1, #T_940f9_row8_col2, #T_940f9_row8_col3 {
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.9%, transparent 21.9%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 15.1%, transparent 15.1%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row0_col6, #T_940f9_row1_col6, #T_940f9_row2_col6, #T_940f9_row3_col6, #T_940f9_row4_col6, #T_940f9_row5_col6, #T_940f9_row6_col6, #T_940f9_row7_col6, #T_940f9_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row0_col7, #T_940f9_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.0%, transparent 13.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 17.1%, transparent 17.1%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row0_col9, #T_940f9_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row0_col10, #T_940f9_row1_col10, #T_940f9_row2_col10, #T_940f9_row3_col10, #T_940f9_row4_col10, #T_940f9_row5_col10, #T_940f9_row6_col10, #T_940f9_row7_col10, #T_940f9_row8_col10 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 46.7%, transparent 46.7%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 19.1%, transparent 19.1%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 33.6%, transparent 33.6%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 49.0%, transparent 49.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 60.6%, transparent 60.6%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 21.4%, transparent 21.4%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row2_col5, #T_940f9_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.3%, transparent 14.3%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 7.1%, transparent 7.1%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.6%, transparent 28.6%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.3%, transparent 9.3%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.1%, transparent 11.1%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 7.4%, transparent 7.4%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.8%, transparent 6.8%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.2%, transparent 10.2%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.7%, transparent 1.7%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.1%, transparent 5.1%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.5%, transparent 8.5%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 19.5%, transparent 19.5%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.5%, transparent 10.5%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.5%, transparent 11.5%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 17.0%, transparent 17.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.8%, transparent 23.8%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row6_col4, #T_940f9_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 40.7%, transparent 40.7%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 22.2%, transparent 22.2%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row6_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 59.3%, transparent 59.3%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row7_col4, #T_940f9_row8_col4, #T_940f9_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 50.0%, transparent 50.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row7_col5, #T_940f9_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.7%, transparent 26.7%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_940f9_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(

# %%
def color_count(df):

    color = []
    nd = pd.DataFrame(df.isna().sum() == 0)
    nd.reset_index(inplace = True)
    nd.columns = ["col", "bool"]
    cut_nd = nd[nd["bool"] == True]
    cut_nd2 = nd[nd["bool"] == False]

    for i in range(len(cut_nd)):
    
        color.append("grey")
    
    for j in range(len(cut_nd2)):
    
        color.append("#fe346e")
    
    return color

fig, ax = plt.subplots(figsize = (12, 4), dpi = 70)
fig.patch.set_facecolor("white")

ax.set_facecolor("white")

msno.bar(data, sort = "descending", color = color_count(data), ax = ax, fontsize = 14, labels = "off", filter = "top")
ax.text(-1, 1.35, "Visualization of Nullity of The Data", {"font": "Serif","size" : 28, "color": "black"}, 
        alpha = 0.9)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90, ha = "center", 
                   **{ "weight": "normal", "color": "#512b58"}, alpha = 1)
ax.set_yticklabels("")
ax.spines["bottom"].set_visible(True)

fig.show()

# %% [markdown]
# 결측값이 존재하지 않음을 확인할 수 있다.

# %% [markdown]
# ### 변수별 이상치 제거

# %%
fig = plt.figure(figsize = (15, 10))

for i, n in enumerate(data.iloc[:, :].columns):
    
    plt.subplot(int(len(data.iloc[:, :].columns) / 3), 3, i + 1)
    plt.boxplot(data[n], labels = [n])

# %%
def outlier_trans(df):
    
    idx = 0
    
    for _, col in enumerate(df.columns):
        
        q75, q25 = np.percentile(df[col], [75, 25])
        iqr = q75 - q25
        ind = df[col][(df[col] > q75 + 1.5 * iqr) | (df[col] < q25 - 1.5 * iqr)].index
    
        if (len(ind) == 0) | (df[col].dtypes == "object"):
            
            idx += 1
    
        else:
            
            for _, n in enumerate(ind):
    
                if df.iloc[n, idx] > q75:
        
                    df.iloc[n, idx] = q75
        
                else:
        
                    df.iloc[n, idx] = q25
            
            idx += 1
    
X_con = data.copy()
outlier_trans(X_con)

fig = plt.figure(figsize = (15, 10))

for i, n in enumerate(data.iloc[:, :].columns):
    
    plt.subplot(int(len(X_con.iloc[:, :].columns) / 3), 3, i + 1)
    plt.boxplot(X_con[n], labels = [n])

# %% [markdown]
# 이상값을 제거하는 것보다는 하한값(25%)과 상한값(75%)을 결정한 후
# 하한값보다 적으면 하한값으로 대체하고 상한값보다 크면 상한값으로 대체하였다.

# %% [markdown]
# ### 단변수 탐색 : 수치형 변수

# %%
fig =  plt.figure(figsize = (15, 10))
g = fig.add_gridspec(3, 3)
g.update(wspace = 0.2, hspace = 0.2)
ax0 = fig.add_subplot(g[0, 0])
ax1 = fig.add_subplot(g[0, 1])
ax2 = fig.add_subplot(g[0, 2])
ax3 = fig.add_subplot(g[1, 0])
ax4 = fig.add_subplot(g[1, 1])
ax5 = fig.add_subplot(g[1, 2])
ax6 = fig.add_subplot(g[2, 0])
ax7 = fig.add_subplot(g[2, 1])
ax8 = fig.add_subplot(g[2, 2])
axes = [ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]



for ax in axes:
    
    ax.tick_params(axis = "x", labelsize = 10, which = "major", direction = "out", pad = 2, length = 1.5)
    ax.tick_params(axis = "y", colors = "black")
    ax.axes.get_yaxis().set_visible(False)
    
    for loc in ["left", "right", "top", "bottom"]:
        ax.spines[loc].set_visible(False)

num_cols = data.dtypes[(data.dtypes == "int64") | (data.dtypes == "float64")].index

sns.kdeplot(x = data[num_cols[0]], fill = True, alpha = 1, ax = ax0, color = "lightgrey")
sns.kdeplot(x = data[num_cols[0]], alpha = 1, ax = ax0, color = "grey")

sns.kdeplot(x = data[num_cols[1]], fill = True, alpha = 1, ax = ax1, color = "lightgrey")
sns.kdeplot(x = data[num_cols[1]], alpha = 1, ax = ax1, color = "grey")

sns.kdeplot(x = data[num_cols[2]], fill = True, alpha = 1, ax = ax2, color = "lightgrey")
sns.kdeplot(x = data[num_cols[2]], alpha = 1, ax = ax2, color = "grey")

sns.kdeplot(x = data[num_cols[3]], fill = True, alpha = 1, ax = ax3, color = "lightgrey")
sns.kdeplot(x = data[num_cols[3]], alpha = 1, ax = ax3, color = "grey")

sns.kdeplot(x = data[num_cols[4]], fill = True, alpha = 1, ax = ax4, color = "lightgrey")
sns.kdeplot(x = data[num_cols[4]], alpha = 1, ax = ax4, color = "grey")

sns.kdeplot(x = data[num_cols[5]], fill = True, alpha = 1, ax = ax5, color = "lightgrey")
sns.kdeplot(x = data[num_cols[5]], alpha = 1, ax = ax5, color = "grey")

sns.kdeplot(x = data[num_cols[6]], fill = True, alpha = 1, ax = ax6, color = "lightgrey")
sns.kdeplot(x = data[num_cols[6]], alpha = 1, ax = ax6, color = "grey")

sns.kdeplot(x = data[num_cols[7]], fill = True, alpha = 1, ax = ax7, color = "lightgrey")
sns.kdeplot(x = data[num_cols[7]], alpha = 1, ax = ax7, color = "grey")

sns.kdeplot(x = data[num_cols[8]], fill = True, alpha = 1, ax = ax8, color = "lightgrey")
sns.kdeplot(x = data[num_cols[8]], alpha = 1, ax = ax8, color = "grey")

fig.text(0.1, 1, "Numeric features distribution" ,**{'font' : 'serif', 'size' : 25, 'weight' : 'bold'}, alpha = 0.9)
fig.show()

# %%
plt.figure(figsize = (10, 10))
corrmat = data.corr().round(2)
g = sns.heatmap(data = corrmat, annot = True, cmap = "Blues", square = True, annot_kws = {"size": 18})
g.text(-1, -1.065, "Correlation of Features", {"font": "serif", "size": 36, "weight": "bold"})
plt.show()
