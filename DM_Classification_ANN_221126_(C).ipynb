# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import datetime as dt
from pandas import read_excel
from pandas import read_csv
from pandas import concat
from pandas import merge
import pandas as pd
import numpy as np
from pandas import Series
from pandas import DataFrame
import re


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler

from statsmodels.formula.api import ols

from matplotlib import pyplot as plt
import seaborn as sns

# %%
import os
os.chdir(r'C:\Users\82102\OneDrive\바탕 화면\dataset\MFC')

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data_for_classification.csv', encoding='UTF8', index_col = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469 entries, 0 to 468
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GAS_STATION   469 non-null    object
#  1   DISTRICT      469 non-null    object
#  2   DONG          469 non-null    object
#  3   LATITUDE      469 non-null    float64
#  4   LONGITUDE     469 non-null    float64
#  5   AREA          469 non-null    float64
#  6   ESTATE        469 non-null    float64
#  7   DIST_EASTDC   469 non-null    float64
#  8   DIST_WESTDC   469 non-null    float64
#  9   DIST_KOREADC  469 non-null    float64
#  10  POP100        469 non-null    int64
#  11  POP500        469 non-null    int64
#  12  POP1000       469 non-null    int64
#  13  SCHOOL        469 non-null    int64
#  14  APART         469 non-null    int64
#  15  MARKET        469 non-null    int64
# dtypes: float64(7), int64(6), object(3)
# memory usage: 62.3+ KB

# %%
df.head()
# Out:
#           GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0  현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1      선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2    현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3               서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4        ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
#
#        ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0   8280000.0     8.970251    13.202286     11.678968     166    4465
# 1  18850000.0     9.568763    12.593357     11.494239     349    7404
# 2  15050000.0     9.713120    12.454393     11.199948     251    7069
# 3  10330000.0     9.772973    12.403577     11.855362     102    8374
# 4  13300000.0    11.006969    11.272070     10.639303     186    5401
#
#    POP1000  SCHOOL  APART  MARKET
# 0    15660       5      1      58
# 1    25467       9      2       6
# 2    26924       9      1      22
# 3    30288       5      2       4
# 4    27394       9      6      20

# %%
## correlation
colormap = plt.cm.viridis
plt.figure(figsize=(15,15))
plt.title('Pearson Correlation of Features', size=15)

sns.heatmap(df.iloc[:,5:].astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
values = df.iloc[:,[5,6,7,8,9,12,13,14,15]]
values = values.values

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_ = MinMaxScaler()
scaler_.fit(values)
scaled_ = scaler_.transform(values)

scaled__df = pd.DataFrame(scaled_, columns=df.columns[[5,6,7,8,9,12,13,14,15]])
scaled__df
# Out:
#          AREA    ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC   POP1000  \
# 0    0.043427  0.189831     0.318940     0.438800      0.443422  0.253190
# 1    0.169609  0.432974     0.341411     0.418207      0.436269  0.411800
# 2    0.166631  0.345562     0.346831     0.413507      0.424874  0.435364
# 3    0.250571  0.236987     0.349078     0.411788      0.450253  0.489771
# 4    0.117620  0.305306     0.395409     0.373522      0.403165  0.442966
# ..        ...       ...          ...          ...           ...       ...
# 464  0.346968  0.096093     0.443528     0.903896      0.970632  0.200805
# 465  0.421350  0.100464     0.427046     0.893226      0.953412  0.300610
# 466  0.050467  0.129816     0.387928     0.863363      0.910698  0.454400
# 467  0.197770  0.123122     0.402324     0.887401      0.930860  0.487522
# 468  0.137116  0.110148     0.335845     0.838629      0.858553  0.555611
#
#        SCHOOL     APART    MARKET
# 0    0.357143  0.018519  0.983051
# 1    0.642857  0.037037  0.101695
# 2    0.642857  0.018519  0.372881
# 3    0.357143  0.037037  0.067797
# 4    0.642857  0.111111  0.338983
# ..        ...       ...       ...
# 464  0.285714  0.018519  0.000000
# 465  0.285714  0.018519  0.000000
# 466  0.000000  0.000000  0.067797
# 467  0.214286  0.018519  0.033898
# 468  0.285714  0.055556  0.067797
#
# [469 rows x 9 columns]

# %% [markdown]
# According to AHP analysis, we set weight of features.
# * Weight
#     - AREA = 0.198
#     - ESTATE = 0.327
#     - DISTANCE = 0.124
#     - POPULATION = 0.244
#     - SCHOOL = 0.02
#     - APARTMENT = 0.04
#     - MARKET = 0.048

# %%
# AHP
dfdf = scaled__df.copy()
dfdf['SCORE'] = dfdf['AREA']*0.198 - dfdf['ESTATE']*0.327 - dfdf['DIST_EASTDC']*0.0413 - dfdf['DIST_WESTDC']*0.0413 - dfdf['DIST_KOREADC']*0.0413 + dfdf['POP1000']*0.244 + dfdf['SCHOOL']*0.02 + dfdf['APART']*0.04 + dfdf['MARKET']*0.048

# %%
dfdf
# Out:
#          AREA    ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC   POP1000  \
# 0    0.043427  0.189831     0.318940     0.438800      0.443422  0.253190
# 1    0.169609  0.432974     0.341411     0.418207      0.436269  0.411800
# 2    0.166631  0.345562     0.346831     0.413507      0.424874  0.435364
# 3    0.250571  0.236987     0.349078     0.411788      0.450253  0.489771
# 4    0.117620  0.305306     0.395409     0.373522      0.403165  0.442966
# ..        ...       ...          ...          ...           ...       ...
# 464  0.346968  0.096093     0.443528     0.903896      0.970632  0.200805
# 465  0.421350  0.100464     0.427046     0.893226      0.953412  0.300610
# 466  0.050467  0.129816     0.387928     0.863363      0.910698  0.454400
# 467  0.197770  0.123122     0.402324     0.887401      0.930860  0.487522
# 468  0.137116  0.110148     0.335845     0.838629      0.858553  0.555611
#
#        SCHOOL     APART    MARKET     SCORE
# 0    0.357143  0.018519  0.983051  0.013764
# 1    0.642857  0.037037  0.101695 -0.037691
# 2    0.642857  0.018519  0.372881  0.008770
# 3    0.357143  0.037037  0.067797  0.053482
# 4    0.642857  0.111111  0.338983  0.016702
# ..        ...       ...       ...       ...
# 464  0.285714  0.018519  0.000000 -0.003007
# 465  0.285714  0.018519  0.000000  0.036476
# 466  0.000000  0.000000  0.067797 -0.007620
# 467  0.214286  0.018519  0.033898  0.032797
# 468  0.285714  0.055556  0.067797  0.053926
#
# [469 rows x 10 columns]

# %%
df['SCORE_CAT'] = pd.qcut(dfdf.SCORE ,4, labels=['매우부적합', '부적합', '적합', '매우적합'])
df
# Out:
#              GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0     현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1         선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2       현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3                  서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4           ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
# ..                   ...      ...    ...        ...         ...     ...
# 464  현대오일뱅크㈜직영 도봉현대셀프주유소      도봉구    도봉동  37.688374  127.045327  1366.0
# 465         GS칼텍스㈜ 도봉주유소      도봉구    도봉동  37.684369  127.045522  1640.7
# 466     (주)송만에너지 도봉제일주유소      도봉구    도봉동  37.674474  127.044067   271.0
# 467               노원교주유소      도봉구    도봉동  37.679015  127.049751   815.0
# 468                오복주유소      도봉구    방학동  37.662280  127.047441   591.0
#
#          ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0     8280000.0     8.970251    13.202286     11.678968     166    4465
# 1    18850000.0     9.568763    12.593357     11.494239     349    7404
# 2    15050000.0     9.713120    12.454393     11.199948     251    7069
# 3    10330000.0     9.772973    12.403577     11.855362     102    8374
# 4    13300000.0    11.006969    11.272070     10.639303     186    5401
# ..          ...          ...          ...           ...     ...     ...
# 464   4205000.0    12.288585    26.954691     25.294460      16    4651
# 465   4395000.0    11.849594    26.639204     24.849744     180    9341
# 466   5671000.0    10.807711    25.756175     23.746627     465    7251
# 467   5380000.0    11.191130    26.466958     24.267332      55    9057
# 468   4816000.0     9.420522    25.024822     22.399970     247    6762
#
#      POP1000  SCHOOL  APART  MARKET SCORE_CAT
# 0      15660       5      1      58       부적합
# 1      25467       9      2       6     매우부적합
# 2      26924       9      1      22       부적합
# 3      30288       5      2       4        적합
# 4      27394       9      6      20       부적합
# ..       ...     ...    ...     ...       ...
# 464    12421       4      1       0     매우부적합
# 465    18592       4      1       0       부적합
# 466    28101       0      0       4     매우부적합
# 467    30149       3      1       2       부적합
# 468    34359       4      3       4        적합
#
# [469 rows x 17 columns]

# %%
feature_cols = df.columns[[5,6,7,8,9,12,13,14,15]]
# define X and y
X = df[feature_cols]
y = df.SCORE_CAT

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1113)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (328, 9) (328,)
# (141, 9) (141,)

# %%
y_train.value_counts()
# Out:
# 부적합      87
# 적합       86
# 매우적합     82
# 매우부적합    73
# Name: SCORE_CAT, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier , AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
clf = DecisionTreeClassifier(random_state=0).fit(X_train, y_train)
predicted=clf.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_clf = 'Accuracy Score :', accuracy_score(y_test, predicted)
print(accuracy_score_clf)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[35  0  9  1]
#  [ 0 33  0  2]
#  [10  0 16  4]
#  [ 0  5  4 22]]
# ('Accuracy Score :', 0.75177304964539)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.78      0.78      0.78        45
#         매우적합       0.87      0.94      0.90        35
#          부적합       0.55      0.53      0.54        30
#           적합       0.76      0.71      0.73        31
#
#     accuracy                           0.75       141
#    macro avg       0.74      0.74      0.74       141
# weighted avg       0.75      0.75      0.75       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , clf.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.210732
# ESTATE                  0.191658
# DIST_EASTDC             0.025755
# DIST_WESTDC             0.047889
# DIST_KOREADC            0.051467
# POP1000                 0.356623
# SCHOOL                  0.041029
# APART                   0.025217
# MARKET                  0.049629

# %%
lr = LogisticRegression(C=20, max_iter=1000, random_state=0).fit(X_train, y_train)
predicted=lr.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_lr = 'Accuracy Score :',accuracy_score(y_test, predicted)
print(accuracy_score_lr)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[31  1 12  1]
#  [ 0 29  3  3]
#  [ 0  3 21  6]
#  [ 1 12  5 13]]
# ('Accuracy Score :', 0.6666666666666666)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.97      0.69      0.81        45
#         매우적합       0.64      0.83      0.73        35
#          부적합       0.51      0.70      0.59        30
#           적합       0.57      0.42      0.48        31
#
#     accuracy                           0.67       141
#    macro avg       0.67      0.66      0.65       141
# weighted avg       0.70      0.67      0.67       141

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=11).fit(X_train_scaled, y_train)
predicted=knn.predict(X_test_scaled)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_knn = 'Accuracy Score :',accuracy_score(y_test, predicted)
print(accuracy_score_knn)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[34  1  9  1]
#  [ 0 26  1  8]
#  [ 3  1 15 11]
#  [ 0  5  7 19]]
# ('Accuracy Score :', 0.6666666666666666)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.92      0.76      0.83        45
#         매우적합       0.79      0.74      0.76        35
#          부적합       0.47      0.50      0.48        30
#           적합       0.49      0.61      0.54        31
#
#     accuracy                           0.67       141
#    macro avg       0.67      0.65      0.66       141
# weighted avg       0.70      0.67      0.68       141

# %%
forest = RandomForestClassifier(max_depth = 12, random_state=0).fit(X_train, y_train)
predicted=forest.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_forest = 'Accuracy Score :',accuracy_score(y_test, predicted)
print(accuracy_score_forest)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[37  0  8  0]
#  [ 0 31  2  2]
#  [ 4  0 19  7]
#  [ 2  7  2 20]]
# ('Accuracy Score :', 0.7588652482269503)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.86      0.82      0.84        45
#         매우적합       0.82      0.89      0.85        35
#          부적합       0.61      0.63      0.62        30
#           적합       0.69      0.65      0.67        31
#
#     accuracy                           0.76       141
#    macro avg       0.74      0.75      0.74       141
# weighted avg       0.76      0.76      0.76       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , forest.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.136232
# ESTATE                  0.159847
# DIST_EASTDC             0.083291
# DIST_WESTDC             0.072984
# DIST_KOREADC            0.091123
# POP1000                 0.301456
# SCHOOL                  0.041859
# APART                   0.069904
# MARKET                  0.043305

# %%
gb = GradientBoostingClassifier(max_depth=7, random_state=0).fit(X_train, y_train)
predicted=gb.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
accuracy_score_gb = 'Accuracy Score :',accuracy_score(y_test, predicted)
print(accuracy_score_gb)
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[38  0  7  0]
#  [ 0 29  1  5]
#  [ 5  0 19  6]
#  [ 0  4  5 22]]
# ('Accuracy Score :', 0.7659574468085106)
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.88      0.84      0.86        45
#         매우적합       0.88      0.83      0.85        35
#          부적합       0.59      0.63      0.61        30
#           적합       0.67      0.71      0.69        31
#
#     accuracy                           0.77       141
#    macro avg       0.76      0.75      0.75       141
# weighted avg       0.77      0.77      0.77       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , gb.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.159759
# ESTATE                  0.211988
# DIST_EASTDC             0.051810
# DIST_WESTDC             0.029212
# DIST_KOREADC            0.071025
# POP1000                 0.399160
# SCHOOL                  0.037593
# APART                   0.026438
# MARKET                  0.013017

# %%
## adaboost나 xgboost나 LGbm하고 싶은데 잘 모르겠음 다중분류라 파라미터 뜯어볼 시간이 없어서 안함.

# %% [markdown]
# ## 찬이 인공신경망 들어가야 할 부분

# %% [markdown]
# 일부러 에러나라고 쓸겡
# y 형식이 아마 int여야하는걸루 알아
# 매우부적합 = 0 부적합 = 1 적합 = 2 매우적합 = 3 이런식으로 이거 먼저 df에 컬럼추가 해주고 그담에 y = df.~~~ 이부분 작성하면 될듯
# 내가 찾은바로는 label encoding 하면 sparse_categorical_crossentropy가 맞대

# %%
df['SCORE_CAT']
# Out:
# 0        부적합
# 1      매우부적합
# 2        부적합
# 3         적합
# 4        부적합
#        ...
# 464    매우부적합
# 465      부적합
# 466    매우부적합
# 467      부적합
# 468       적합
# Name: SCORE_CAT, Length: 469, dtype: category
# Categories (4, object): ['매우부적합' < '부적합' < '적합' < '매우적합']

# %%
# 라벨 인코딩
# 1대1 매칭시켜도 되는데
# 수업 컨텐츠 사용할려고
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['SCORE_CAT'])
label_encoded = le.transform(df['SCORE_CAT'])


label_df = pd.DataFrame(label_encoded, 
                       columns = ['Score_label'])

label_df.head()
# Out:
#    Score_label
# 0            2
# 1            0
# 2            2
# 3            3
# 4            2

# %%
# 매우부적합 : 0
# 부적합 : 2
# 적합 : 3
# 매우적합 : 1
df_ann = pd.concat([df, label_df], axis =  1)
df_ann.head()
# Out:
#           GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0  현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1      선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2    현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3               서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4        ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
#
#        ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0   8280000.0     8.970251    13.202286     11.678968     166    4465
# 1  18850000.0     9.568763    12.593357     11.494239     349    7404
# 2  15050000.0     9.713120    12.454393     11.199948     251    7069
# 3  10330000.0     9.772973    12.403577     11.855362     102    8374
# 4  13300000.0    11.006969    11.272070     10.639303     186    5401
#
#    POP1000  SCHOOL  APART  MARKET SCORE_CAT  Score_label
# 0    15660       5      1      58       부적합            2
# 1    25467       9      2       6     매우부적합            0
# 2    26924       9      1      22       부적합            2
# 3    30288       5      2       4        적합            3
# 4    27394       9      6      20       부적합            2

# %%
feature_cols = df_ann.columns[[5,6,7,8,9,12,13,14,15]]
# define X and y
X = df_ann[feature_cols]
y = df_ann['Score_label']

# %%
# (x_train, y_train), (x_test, y_test) 데이터 나누기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1113)

# %%
# 데이터 정규화해서 스케일 낮추기
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# train 데이터 분리 (train/valid)
train_scaled, val_scaled, train_target, val_target = train_test_split(X_train_scaled, y_train, test_size=0.3, random_state=1113)

# %%
# dense 조합 바꿔가면서 보기
neural_model = Sequential()

neural_model.add(Dense(64, activation = 'relu', input_shape = (9, )))
neural_model.add(Dense(32, activation = 'relu'))
neural_model.add(Dense(8, activation = 'relu'))
neural_model.add(Dense(4, activation = 'softmax'))


neural_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['sparse_categorical_accuracy']) 
neural_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                640
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 8)                 264
#
#  dense_3 (Dense)             (None, 4)                 36
#
# =================================================================
# Total params: 3,020
# Trainable params: 3,020
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = neural_model.fit(train_scaled, train_target, epochs = 1000, validation_data = (val_scaled, val_target),
                         callbacks = [EarlyStopping(monitor = 'val_loss', patience=10, verbose = 1),
                                     ReduceLROnPlateau(monitor = 'val_loss', patience = 10, factor = 0.1, min_lr=0.0001, verbose = 1)])


result_df = pd.DataFrame(result.history)
result_df['score'] = result_df.index+1
result_df.set_index('score', inplace = True)
result_df
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 3s 134ms/step - loss: 1.3900 - sparse_categorical_accuracy: 0.2620 - val_loss: 1.3966 - val_sparse_categorical_accuracy: 0.2323 - lr: 0.0010
# Epoch 2/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.3782 - sparse_categorical_accuracy: 0.3668 - val_loss: 1.3826 - val_sparse_categorical_accuracy: 0.3030 - lr: 0.0010
# Epoch 3/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 1.3718 - sparse_categorical_accuracy: 0.4105 - val_loss: 1.3787 - val_sparse_categorical_accuracy: 0.3131 - lr: 0.0010
# Epoch 4/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 1.3633 - sparse_categorical_accuracy: 0.3799 - val_loss: 1.3790 - val_sparse_categorical_accuracy: 0.3030 - lr: 0.0010
# Epoch 5/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 1.3524 - sparse_categorical_accuracy: 0.3624 - val_loss: 1.3755 - val_sparse_categorical_accuracy: 0.2929 - lr: 0.0010
# Epoch 6/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 1.3402 - sparse_categorical_accuracy: 0.3755 - val_loss: 1.3655 - val_sparse_categorical_accuracy: 0.3333 - lr: 0.0010
# Epoch 7/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.3279 - sparse_categorical_accuracy: 0.4236 - val_loss: 1.3532 - val_sparse_categorical_accuracy: 0.3535 - lr: 0.0010
# Epoch 8/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 1.3125 - sparse_categorical_accuracy: 0.4410 - val_loss: 1.3412 - val_sparse_categorical_accuracy: 0.3333 - lr: 0.0010
# Epoch 9/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.2970 - sparse_categorical_accuracy: 0.3712 - val_loss: 1.3308 - val_sparse_categorical_accuracy: 0.2929 - lr: 0.0010
# Epoch 10/1000
# 8/8 [==============================] - 0s 33ms/step - loss: 1.2811 - sparse_categorical_accuracy: 0.4105 - val_loss: 1.3149 - val_sparse_categorical_accuracy: 0.3333 - lr: 0.0010
# Epoch 11/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 1.2650 - sparse_categorical_accuracy: 0.4367 - val_loss: 1.3038 - val_sparse_categorical_accuracy: 0.3636 - lr: 0.0010
# Epoch 12/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.2495 - sparse_categorical_accuracy: 0.4410 - val_loss: 1.2824 - val_sparse_categorical_accuracy: 0.3838 - lr: 0.0010
# Epoch 13/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.2337 - sparse_categorical_accuracy: 0.5109 - val_loss: 1.2667 - val_sparse_categorical_accuracy: 0.4343 - lr: 0.0010
# Epoch 14/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.2161 - sparse_categorical_accuracy: 0.5022 - val_loss: 1.2532 - val_sparse_categorical_accuracy: 0.3838 - lr: 0.0010
# Epoch 15/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1987 - sparse_categorical_accuracy: 0.5153 - val_loss: 1.2344 - val_sparse_categorical_accuracy: 0.4444 - lr: 0.0010
# Epoch 16/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 1.1802 - sparse_categorical_accuracy: 0.5153 - val_loss: 1.2244 - val_sparse_categorical_accuracy: 0.3939 - lr: 0.0010
# Epoch 17/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 1.1687 - sparse_categorical_accuracy: 0.5022 - val_loss: 1.2096 - val_sparse_categorical_accuracy: 0.4343 - lr: 0.0010
# Epoch 18/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 1.1473 - sparse_categorical_accuracy: 0.5328 - val_loss: 1.1899 - val_sparse_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 19/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1304 - sparse_categorical_accuracy: 0.4716 - val_loss: 1.1711 - val_sparse_categorical_accuracy: 0.3838 - lr: 0.0010
# Epoch 20/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.1144 - sparse_categorical_accuracy: 0.4760 - val_loss: 1.1523 - val_sparse_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 21/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 1.1019 - sparse_categorical_accuracy: 0.4803 - val_loss: 1.1350 - val_sparse_categorical_accuracy: 0.4343 - lr: 0.0010
# Epoch 22/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0859 - sparse_categorical_accuracy: 0.4716 - val_loss: 1.1245 - val_sparse_categorical_accuracy: 0.4040 - lr: 0.0010
# Epoch 23/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 1.0694 - sparse_categorical_accuracy: 0.4803 - val_loss: 1.1077 - val_sparse_categorical_accuracy: 0.4040 - lr: 0.0010
# Epoch 24/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 1.0507 - sparse_categorical_accuracy: 0.4934 - val_loss: 1.0903 - val_sparse_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 25/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 1.0368 - sparse_categorical_accuracy: 0.5153 - val_loss: 1.0666 - val_sparse_categorical_accuracy: 0.4545 - lr: 0.0010
# Epoch 26/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 1.0193 - sparse_categorical_accuracy: 0.5240 - val_loss: 1.0546 - val_sparse_categorical_accuracy: 0.4242 - lr: 0.0010
# Epoch 27/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0018 - sparse_categorical_accuracy: 0.5240 - val_loss: 1.0412 - val_sparse_categorical_accuracy: 0.4444 - lr: 0.0010
# Epoch 28/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.9811 - sparse_categorical_accuracy: 0.5459 - val_loss: 1.0191 - val_sparse_categorical_accuracy: 0.4747 - lr: 0.0010
# Epoch 29/1000
# 8/8 [==============================] - 0s 29ms/step - loss: 0.9662 - sparse_categorical_accuracy: 0.5764 - val_loss: 0.9978 - val_sparse_categorical_accuracy: 0.4848 - lr: 0.0010
# Epoch 30/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.9462 - sparse_categorical_accuracy: 0.5939 - val_loss: 0.9894 - val_sparse_categorical_accuracy: 0.5051 - lr: 0.0010
# Epoch 31/1000
# 8/8 [==============================] - 0s 36ms/step - loss: 0.9311 - sparse_categorical_accuracy: 0.5721 - val_loss: 0.9710 - val_sparse_categorical_accuracy: 0.4848 - lr: 0.0010
# Epoch 32/1000
# 8/8 [==============================] - 0s 36ms/step - loss: 0.9070 - sparse_categorical_accuracy: 0.5895 - val_loss: 0.9498 - val_sparse_categorical_accuracy: 0.4949 - lr: 0.0010
# Epoch 33/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.8855 - sparse_categorical_accuracy: 0.6157 - val_loss: 0.9300 - val_sparse_categorical_accuracy: 0.5051 - lr: 0.0010
# Epoch 34/1000
# 8/8 [==============================] - 0s 35ms/step - loss: 0.8665 - sparse_categorical_accuracy: 0.6201 - val_loss: 0.9074 - val_sparse_categorical_accuracy: 0.5455 - lr: 0.0010
# Epoch 35/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.8469 - sparse_categorical_accuracy: 0.6332 - val_loss: 0.8918 - val_sparse_categorical_accuracy: 0.5758 - lr: 0.0010
# Epoch 36/1000
# 8/8 [==============================] - 0s 47ms/step - loss: 0.8284 - sparse_categorical_accuracy: 0.6507 - val_loss: 0.8690 - val_sparse_categorical_accuracy: 0.6263 - lr: 0.0010
# Epoch 37/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.8072 - sparse_categorical_accuracy: 0.6463 - val_loss: 0.8431 - val_sparse_categorical_accuracy: 0.6162 - lr: 0.0010
# Epoch 38/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7882 - sparse_categorical_accuracy: 0.6725 - val_loss: 0.8198 - val_sparse_categorical_accuracy: 0.6465 - lr: 0.0010
# Epoch 39/1000
# 8/8 [==============================] - 0s 29ms/step - loss: 0.7671 - sparse_categorical_accuracy: 0.6681 - val_loss: 0.8089 - val_sparse_categorical_accuracy: 0.6364 - lr: 0.0010
# Epoch 40/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.7439 - sparse_categorical_accuracy: 0.6769 - val_loss: 0.7852 - val_sparse_categorical_accuracy: 0.6061 - lr: 0.0010
# Epoch 41/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.7239 - sparse_categorical_accuracy: 0.6681 - val_loss: 0.7680 - val_sparse_categorical_accuracy: 0.6364 - lr: 0.0010
# Epoch 42/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.7180 - sparse_categorical_accuracy: 0.6769 - val_loss: 0.7642 - val_sparse_categorical_accuracy: 0.5960 - lr: 0.0010
# Epoch 43/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7221 - sparse_categorical_accuracy: 0.6288 - val_loss: 0.7336 - val_sparse_categorical_accuracy: 0.6364 - lr: 0.0010
# Epoch 44/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6657 - sparse_categorical_accuracy: 0.6856 - val_loss: 0.7122 - val_sparse_categorical_accuracy: 0.6162 - lr: 0.0010
# Epoch 45/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6553 - sparse_categorical_accuracy: 0.6638 - val_loss: 0.6939 - val_sparse_categorical_accuracy: 0.6364 - lr: 0.0010
# Epoch 46/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6302 - sparse_categorical_accuracy: 0.6681 - val_loss: 0.6586 - val_sparse_categorical_accuracy: 0.6566 - lr: 0.0010
# Epoch 47/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6097 - sparse_categorical_accuracy: 0.6900 - val_loss: 0.6472 - val_sparse_categorical_accuracy: 0.6667 - lr: 0.0010
# Epoch 48/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 0.5934 - sparse_categorical_accuracy: 0.6943 - val_loss: 0.6189 - val_sparse_categorical_accuracy: 0.6667 - lr: 0.0010
# Epoch 49/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5619 - sparse_categorical_accuracy: 0.7031 - val_loss: 0.6147 - val_sparse_categorical_accuracy: 0.6667 - lr: 0.0010
# Epoch 50/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.5494 - sparse_categorical_accuracy: 0.6987 - val_loss: 0.5848 - val_sparse_categorical_accuracy: 0.6566 - lr: 0.0010
# Epoch 51/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.5241 - sparse_categorical_accuracy: 0.7074 - val_loss: 0.5665 - val_sparse_categorical_accuracy: 0.6970 - lr: 0.0010
# Epoch 52/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.5064 - sparse_categorical_accuracy: 0.8166 - val_loss: 0.5426 - val_sparse_categorical_accuracy: 0.8687 - lr: 0.0010
# Epoch 53/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 0.5010 - sparse_categorical_accuracy: 0.8865 - val_loss: 0.5215 - val_sparse_categorical_accuracy: 0.8586 - lr: 0.0010
# Epoch 54/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4661 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.5096 - val_sparse_categorical_accuracy: 0.8485 - lr: 0.0010
# Epoch 55/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.4582 - sparse_categorical_accuracy: 0.8908 - val_loss: 0.4841 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 56/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.4368 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.4637 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 57/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4174 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.4626 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 58/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.4114 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.4248 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 59/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3920 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.4199 - val_sparse_categorical_accuracy: 0.8990 - lr: 0.0010
# Epoch 60/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.3720 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.3967 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 61/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.3619 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.3839 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 62/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 0.3493 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.3832 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 63/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.3287 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.3567 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 64/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 0.3167 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.3406 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 65/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.3046 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.3410 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 66/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.3061 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.3202 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 67/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2930 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.3195 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 68/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2715 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.3055 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 69/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2755 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.3016 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 70/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.2687 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.3112 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 71/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.2597 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.2821 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 72/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2482 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.3057 - val_sparse_categorical_accuracy: 0.8990 - lr: 0.0010
# Epoch 73/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2473 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2646 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 74/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.2461 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.2605 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 75/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2350 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.2930 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 76/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2658 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.2679 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 77/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2302 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2592 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 78/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.2101 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2403 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 79/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2166 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2355 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 80/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.2035 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2283 - val_sparse_categorical_accuracy: 0.9697 - lr: 0.0010
# Epoch 81/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1994 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2284 - val_sparse_categorical_accuracy: 0.9697 - lr: 0.0010
# Epoch 82/1000
# 8/8 [==============================] - 0s 36ms/step - loss: 0.2018 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2471 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 83/1000
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1941 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.2159 - val_sparse_categorical_accuracy: 0.9697 - lr: 0.0010
# Epoch 84/1000
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1876 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2304 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 85/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1835 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.2144 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 86/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1794 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.2211 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 87/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1790 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.2169 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 88/1000
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1730 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.2072 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 89/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1757 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2183 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 90/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1673 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.2032 - val_sparse_categorical_accuracy: 0.9697 - lr: 0.0010
# Epoch 91/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1639 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.2029 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 92/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1717 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2189 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 93/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1803 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.1968 - val_sparse_categorical_accuracy: 0.9697 - lr: 0.0010
# Epoch 94/1000
# 8/8 [==============================] - 0s 25ms/step - loss: 0.1705 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2283 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 95/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1561 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1967 - val_sparse_categorical_accuracy: 0.9697 - lr: 0.0010
# Epoch 96/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1572 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.2234 - val_sparse_categorical_accuracy: 0.8990 - lr: 0.0010
# Epoch 97/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1624 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1907 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 98/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1495 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1893 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 99/1000
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1506 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1954 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 100/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1536 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1774 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 101/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1416 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1807 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 102/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1493 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.1997 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 103/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1433 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1804 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 104/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1348 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1959 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 105/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1370 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1813 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 106/1000
# 8/8 [==============================] - 0s 29ms/step - loss: 0.1400 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.2271 - val_sparse_categorical_accuracy: 0.8788 - lr: 0.0010
# Epoch 107/1000
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1518 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2037 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 108/1000
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1769 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 109/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1755 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 110/1000
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1253 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1684 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 111/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1522 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2663 - val_sparse_categorical_accuracy: 0.8788 - lr: 0.0010
# Epoch 112/1000
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1630 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.1734 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 113/1000
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1324 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1916 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 114/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1239 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1680 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 115/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1168 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1950 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 116/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 0.1385 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.1688 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 117/1000
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1370 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2328 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 118/1000
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1298 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.2065 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 119/1000
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.2767 - val_sparse_categorical_accuracy: 0.8485 - lr: 0.0010
# Epoch 120/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1432 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.1752 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 121/1000
# 8/8 [==============================] - 0s 32ms/step - loss: 0.1479 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.1842 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 122/1000
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1754 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 123/1000
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1088 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.1628 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 124/1000
# 8/8 [==============================] - 0s 37ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1836 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 125/1000
# 8/8 [==============================] - 0s 34ms/step - loss: 0.1152 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1645 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 126/1000
# 8/8 [==============================] - 0s 35ms/step - loss: 0.1201 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1977 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 127/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1163 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1615 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 128/1000
# 8/8 [==============================] - 0s 33ms/step - loss: 0.1080 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1613 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 129/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 0.1027 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1704 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 130/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1011 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.1865 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 131/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1180 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1570 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 132/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1132 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2079 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 133/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.1054 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1615 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 134/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 0.1083 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.1659 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 135/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1033 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1519 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 136/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.1089 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1950 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 137/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.1278 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1682 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 138/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1131 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1890 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 139/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.0950 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.1545 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 140/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 0.0922 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1789 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 141/1000
# 8/8 [==============================] - 0s 27ms/step - loss: 0.1059 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1528 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 142/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1062 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1574 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 143/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0966 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1571 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 144/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.1826 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 145/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0882 - sparse_categorical_accuracy: 1.0000
# Epoch 145: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 8/8 [==============================] - 0s 26ms/step - loss: 0.0991 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1741 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 145: early stopping
#            loss  sparse_categorical_accuracy  val_loss  \
# score
# 1      1.390043                     0.262009  1.396644
# 2      1.378235                     0.366812  1.382631
# 3      1.371756                     0.410480  1.378690
# 4      1.363260                     0.379913  1.379002
# 5      1.352447                     0.362445  1.375458
# ...         ...                          ...       ...
# 141    0.105927                     0.978166  0.152815
# 142    0.106176                     0.965065  0.157350
# 143    0.096648                     0.973799  0.157098
# 144    0.095371                     0.986900  0.182554
# 145    0.099147                     0.969432  0.174054
#
#        val_sparse_categorical_accuracy     lr
# score
# 1                             0.232323  0.001
# 2                             0.303030  0.001
# 3                             0.313131  0.001
# 4                             0.303030  0.001
# 5                             0.292929  0.001
# ...                                ...    ...
# 141                           0.919192  0.001
# 142                           0.919192  0.001
# 143                           0.919192  0.001
# 144                           0.909091  0.001
# 145                           0.929293  0.001
#
# [145 rows x 5 columns]

# %%
# 손실률(loss) /  절대오차(mean absolute error)에 대한 그래프 설정
plt.rcParams['font.family'] = 'Gulim'
plt.rcParams['font.size'] = 15
plt.rcParams['axes.unicode_minus'] = False

# 그래프 그리기 위한 객체 생성
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 5), dpi = 150)

# 1) 훈련 및 검증 손실 plotting
sns.lineplot(data = result_df, x = result_df.index, y = 'loss', color = 'darkblue', label = 'train 손실률', ax = ax1)
sns.lineplot(data = result_df, x = result_df.index, y = 'val_loss', color = 'orange', label = 'valid 손실률', ax = ax1)
ax1.set_title('훈련 및 검증 손실률')
ax1.set_xlabel('반복회차(Epoch)')
ax1.set_ylabel('손실률(Loss)')
ax1.grid()
ax1.legend()

# 2) 훈련 및 검증 절대오차 plotting
sns.lineplot(data = result_df, x = result_df.index, y = 'sparse_categorical_accuracy', color = 'darkblue', label = 'train accuracy', ax = ax2)
sns.lineplot(data = result_df, x = result_df.index, y = 'val_sparse_categorical_accuracy', color = 'orange', label = 'test val_accuracy', ax = ax2)
ax2.set_title('훈련 및 검증 accuracy')
ax2.set_xlabel('반복회차(Epoch)')
ax2.set_ylabel('accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# Accuracy
let_evaluate = neural_model.evaluate(X_test_scaled, y_test)
print('최종 손실률 : %f, 최종 accuracy : %f' % (let_evaluate[0], let_evaluate[1]))
# Out:
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1396 - sparse_categorical_accuracy: 0.9574
# 최종 손실률 : 0.139630, 최종 accuracy : 0.957447

# %%
# 예측하기
prediction = neural_model.predict(X_test_scaled)
prediction[:10] # 10개 클래스에 관해서 예측값이ㅣ 어레이로 출력됨 따라서 argmax로 최대값 인덱스(위치) 출력
# Out:
# 5/5 [==============================] - 0s 5ms/step
# array([[9.99956608e-01, 4.33001365e-23, 4.33726527e-05, 1.14787665e-10],
#        [3.33777815e-03, 3.03073393e-05, 7.45503366e-01, 2.51128495e-01],
#        [9.97246623e-01, 2.32303305e-22, 2.75336253e-03, 1.17855781e-09],
#        [9.99999881e-01, 1.25036217e-32, 8.85897009e-08, 1.98871332e-16],
#        [3.30080949e-02, 3.42709749e-11, 9.66778696e-01, 2.13201944e-04],
#        [5.15041654e-09, 9.96016085e-01, 9.94569760e-08, 3.98374675e-03],
#        [6.35128004e-08, 9.90186453e-01, 9.60629905e-07, 9.81254037e-03],
#        [1.41243893e-03, 3.51060425e-09, 9.98096526e-01, 4.91030863e-04],
#        [3.84053747e-05, 7.62371463e-04, 7.78758386e-03, 9.91411567e-01],
#        [9.94836092e-01, 6.36336231e-18, 5.16390847e-03, 3.60347769e-08]],
#       dtype=float32)

# %%
# 매우부적합 : 0
# 부적합 : 2
# 적합 : 3
# 매우적합 : 1

df_tmp1 = pd.DataFrame({
    'Actual_Location_Score' :y_test[:10],
    'Predicted_value_by_ANN' : np.argmax(prediction[:10], axis = 1)
})

df_tmp2 = df.iloc[[118,216,276,387, 383, 406, 147, 372, 401, 374], [0,1,2,16]]
pd.concat([df_tmp2, df_tmp1], axis= 1)
# Out:
#              GAS_STATION DISTRICT DONG SCORE_CAT  Actual_Location_Score  \
# 118                삼융주유소      은평구  수색동     매우부적합                      0
# 216    현대오일뱅크㈜직영 신오류주유소       구로구  오류동       부적합                      2
# 276      지에스칼텍스(주) 신월주유소      강동구  성내동     매우부적합                      0
# 387     현대오일뱅크(주) 팔레스주유소      서초구  반포동     매우부적합                      0
# 383  현대오일뱅크(주) 직영방배현대주유소      서초구  방배동       부적합                      2
# 406                신성주유소      노원구  월계동      매우적합                      1
# 147         에이치지 가로공원주유소      양천구  신월동      매우적합                      1
# 372                한독주유소      서초구  방배동       부적합                      2
# 401        대성산업(주)터미널주유소      서초구  반포동        적합                      3
# 374      지에스칼텍스(주)헌릉로주유소      서초구  내곡동     매우부적합                      0
#
#      Predicted_value_by_ANN
# 118                       0
# 216                       2
# 276                       0
# 387                       0
# 383                       2
# 406                       1
# 147                       1
# 372                       2
# 401                       3
# 374                       0

# %%
# !pip3 install plotnine
# Out:
# Requirement already satisfied: plotnine in c:\users\82102\anaconda3\lib\site-packages (0.10.1)
# WARNING: Ignoring invalid distribution -lotly (c:\users\82102\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\82102\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\82102\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\82102\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\82102\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\82102\anaconda3\lib\site-packages)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\82102\anaconda3\lib\site-packages (from plotnine) (1.23.4)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\82102\appdata\roaming\python\python38\site-packages (from plotnine) (0.13.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\82102\anaconda3\lib\site-packages (from plotnine) (1.9.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\82102\appdata\roaming\python\python38\site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\82102\anaconda3\lib\site-packages (from plotnine) (1.4.4)
# Requirement already satisfied: mizani>=0.8.1 in c:\users\82102\anaconda3\lib\site-packages (from plotnine) (0.8.1)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\82102\anaconda3\lib\site-packages (from plotnine) (3.5.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (3.0.9)
# Requirement already satisfied: tzdata in c:\users\82102\anaconda3\lib\site-packages (from mizani>=0.8.1->plotnine) (2022.6)
# Requirement already satisfied: palettable in c:\users\82102\anaconda3\lib\site-packages (from mizani>=0.8.1->plotnine) (3.3.0)
# Requirement already satisfied: backports.zoneinfo in c:\users\82102\anaconda3\lib\site-packages (from mizani>=0.8.1->plotnine) (0.2.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\82102\anaconda3\lib\site-packages (from pandas>=1.3.5->plotnine) (2022.1)
# Requirement already satisfied: six in c:\users\82102\anaconda3\lib\site-packages (from patsy>=0.5.1->plotnine) (1.15.0)

# %%
import plotnine
from plotnine import *

# %%
df_accuracy = pd.DataFrame({
    'Algorithm' : ['Logistic_Reg',  'Knn', 'Decision Tree', 'Random_forest','Gradient_boosting_classifi', 'ANN'],
    'Score': [round(accuracy_score_lr[1],4),round(accuracy_score_knn[1],4),  round(accuracy_score_clf[1], 4), 
              round(accuracy_score_forest[1], 4),
             round(accuracy_score_gb[1], 4), 
              round(let_evaluate[1], 3)]})
df_accuracy
# Out:
#                     Algorithm   Score
# 0                Logistic_Reg  0.6667
# 1                         Knn  0.6667
# 2               Decision Tree  0.7518
# 3               Random_forest  0.7589
# 4  Gradient_boosting_classifi  0.7660
# 5                         ANN  0.9570

# %%
p = ggplot(df_accuracy, aes(x = 'Algorithm',
                            y = 'Score',
                            fill = 'Algorithm',)) + geom_col(alpha = 0.7)
p + coord_flip() + geom_text(aes(label = 'Score')) + ggtitle('Comparison of accuracy by algorithm')
# Out:
# <ggplot: (111654301178)>

# %% [markdown]
# ## 부록

# %%
import folium as g

# %%
# 서울 시 내 MFC 장소로 적합한 주유소 위치후보.
seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(df[df['SCORE_CAT'] == '적합'])):
    marker = g.Marker([df[df['SCORE_CAT'] == '적합']['LATITUDE'].iloc[i], df[df['SCORE_CAT'] == '적합']['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'))
    marker.add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_38cda0ff176d478783c0b90f36e1d3d2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_38cda0ff176d478783c0b90f36e1d3d2%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_38cda0ff176d478783c0b90f36e1d3d2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_38cda0ff176d478783c0b90f36e1d3d2%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# groupby 집계함수로 구별로 max값 추출한 뒤 클러스터링 결과와 결합하여 구당 하나의 최적 위치 설정.
optdf = df.groupby('DISTRICT').max().loc[['동대문구', '양천구', '동작구', '송파구', '구로구', '서대문구', '영등포구']].reset_index()
optdf
# Out:
#   DISTRICT           GAS_STATION    DONG   LATITUDE   LONGITUDE    AREA  \
# 0     동대문구   현대오일뱅크㈜ 직영 스피드 주유소      휘경동  37.603648  127.069418  2080.0
# 1      양천구            형산석유㈜ 원주유소     신정동  37.546767  126.882153  2056.0
# 2      동작구        현대오일뱅크㈜흑석셀프주유소     흑석동  37.513554  126.981970  1676.0
# 3      송파구                훼미리주유소     풍납동  37.527012  127.147838  2586.0
# 4      구로구     현대오일뱅크㈜직영 신오류주유소       항동  37.507698  126.899784  1971.0
# 5     서대문구    현대오일뱅크(주) 직영 연세주유소     홍제동  37.595442  126.950102  1260.0
# 6     영등포구  현대오일뱅크㈜직영 영등포현대셀프주유소  영등포동7가  37.538442  126.927479  3321.0
#
#        ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0   8772000.0     3.507059    22.430746     16.001545     635   12307
# 1  12630000.0    22.271100     5.519070     20.531385     539   12174
# 2  18440000.0    18.113277    12.875900     12.052601     952   11637
# 3  19500000.0    12.966467    27.233535     10.609878     647   15815
# 4  11520000.0    24.241182     6.155432     19.234698    1583   10820
# 5  12900000.0    13.745000    13.589265     16.916960     416    9806
# 6  26900000.0    18.157095     7.964661     15.493111    1383   12158
#
#    POP1000  SCHOOL  APART  MARKET SCORE_CAT
# 0    43733      10     21      14      매우적합
# 1    51685       5     49       7      매우적합
# 2    46479      10      7       5      매우적합
# 3    42885       3     13      10      매우적합
# 4    42423       5      9       7      매우적합
# 5    34119      12      8      10      매우적합
# 6    39557      11     15      17      매우적합

# %%
# 서울 시 내 입지순위 1위 지역 MFC 장소로 적합한 주유소 위치. 지도 시각화, 기호 누르면 해당 주유소의 이름과 위경도 추출해줌.
seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(optdf)):
    name = optdf.iloc[i, 1]
    lat = optdf.iloc[i, 3]
    long = optdf.iloc[i, 4]
    popup = g.Popup('<b>'+name+'</b><br>' + 'Latitude : ' + str(lat) + '<br>Longitude : '+ str(long), max_width=300)
    marker = g.Marker([optdf['LATITUDE'].iloc[i], optdf['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'), popup=popup)
    marker.add_to(seoul_map)

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f52f898750364ad1b99b8bb682e00e29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f52f898750364ad1b99b8bb682e00e29%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f52f898750364ad1b99b8bb682e00e29%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f52f898750364ad1b99b8bb682e00e29%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# # 부록 2 pycaret

# %%
# !pip install --pre pycaret

# %%
from pycaret.classification import *

# %%
s = setup(df.iloc[:,[5,6,7,8,9,12,13,14,15,16]], target = 'SCORE_CAT')

# %%
top5_models = compare_models(fold = 5, round = 3, sort = 'AUC', n_select = 5)

# %%
top5_models

# %%
model_qda = create_model('qda', fold = 5)
model_lda = create_model('lda', fold = 5)
model_lightgbm = create_model('lightgbm', fold = 5)
model_gbc = create_model('gbc', fold = 5)
model_xgboost = create_model('xgboost', fold = 5)

# %%
total_models = []
total_models.append([model_qda, model_lda, model_lightgbm, model_gbc, model_xgboost])

# %%
total_models

# %%
model_qda = tune_model(model_qda, fold=5, optimize = 'AUC', choose_better = True)
model_lda = tune_model(model_lda, fold=5, optimize = 'AUC', choose_better = True)
model_lightgbm = tune_model(model_lightgbm, fold=5, optimize = 'AUC', choose_better = True)
model_gbc = tune_model(model_gbc, fold=5, optimize = 'AUC', choose_better = True)
model_xgboost = tune_model(model_xgboost, fold=5, optimize = 'AUC', choose_better = True)

# %%
tuned_models = [model_qda, model_lda, model_lightgbm, model_gbc, model_xgboost]

# %%
tuned_models

# %%
total_models

# %%
plot_model(model_xgboost, plot='auc')

# %%
plot_model(model_xgboost, plot='feature')
