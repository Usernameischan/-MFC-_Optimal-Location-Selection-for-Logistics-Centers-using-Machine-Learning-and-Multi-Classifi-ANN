# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import datetime as dt
from pandas import read_excel
from pandas import read_csv
from pandas import concat
from pandas import merge
import pandas as pd
import numpy as np
from pandas import Series
from pandas import DataFrame
import re


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.preprocessing import StandardScaler

from statsmodels.formula.api import ols

from matplotlib import pyplot as plt
import seaborn as sns

# %%
import os
os.chdir(r'C:\Users\82102\OneDrive\바탕 화면\dataset\MFC')

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data_for_classification.csv', encoding='UTF8', index_col = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469 entries, 0 to 468
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GAS_STATION   469 non-null    object
#  1   DISTRICT      469 non-null    object
#  2   DONG          469 non-null    object
#  3   LATITUDE      469 non-null    float64
#  4   LONGITUDE     469 non-null    float64
#  5   AREA          469 non-null    float64
#  6   ESTATE        469 non-null    float64
#  7   DIST_EASTDC   469 non-null    float64
#  8   DIST_WESTDC   469 non-null    float64
#  9   DIST_KOREADC  469 non-null    float64
#  10  POP100        469 non-null    int64
#  11  POP500        469 non-null    int64
#  12  POP1000       469 non-null    int64
#  13  SCHOOL        469 non-null    int64
#  14  APART         469 non-null    int64
#  15  MARKET        469 non-null    int64
# dtypes: float64(7), int64(6), object(3)
# memory usage: 62.3+ KB

# %%
df.head()
# Out:
#           GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0  현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1      선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2    현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3               서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4        ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
#
#        ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0   8280000.0     8.970251    13.202286     11.678968     166    4465
# 1  18850000.0     9.568763    12.593357     11.494239     349    7404
# 2  15050000.0     9.713120    12.454393     11.199948     251    7069
# 3  10330000.0     9.772973    12.403577     11.855362     102    8374
# 4  13300000.0    11.006969    11.272070     10.639303     186    5401
#
#    POP1000  SCHOOL  APART  MARKET
# 0    15660       5      1      58
# 1    25467       9      2       6
# 2    26924       9      1      22
# 3    30288       5      2       4
# 4    27394       9      6      20

# %%
## correlation
colormap = plt.cm.viridis
plt.figure(figsize=(15,15))
plt.title('Pearson Correlation of Features', size=15)

sns.heatmap(df.iloc[:,5:].astype(float).corr(),linewidths=0.1,vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
values = df.iloc[:,[5,6,7,8,9,12,13,14,15]]
values = values.values

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_ = MinMaxScaler()
scaler_.fit(values)
scaled_ = scaler_.transform(values)

scaled__df = pd.DataFrame(scaled_, columns=df.columns[[5,6,7,8,9,12,13,14,15]])
scaled__df
# Out:
#          AREA    ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC   POP1000  \
# 0    0.043427  0.189831     0.318940     0.438800      0.443422  0.253190
# 1    0.169609  0.432974     0.341411     0.418207      0.436269  0.411800
# 2    0.166631  0.345562     0.346831     0.413507      0.424874  0.435364
# 3    0.250571  0.236987     0.349078     0.411788      0.450253  0.489771
# 4    0.117620  0.305306     0.395409     0.373522      0.403165  0.442966
# ..        ...       ...          ...          ...           ...       ...
# 464  0.346968  0.096093     0.443528     0.903896      0.970632  0.200805
# 465  0.421350  0.100464     0.427046     0.893226      0.953412  0.300610
# 466  0.050467  0.129816     0.387928     0.863363      0.910698  0.454400
# 467  0.197770  0.123122     0.402324     0.887401      0.930860  0.487522
# 468  0.137116  0.110148     0.335845     0.838629      0.858553  0.555611
#
#        SCHOOL     APART    MARKET
# 0    0.357143  0.018519  0.983051
# 1    0.642857  0.037037  0.101695
# 2    0.642857  0.018519  0.372881
# 3    0.357143  0.037037  0.067797
# 4    0.642857  0.111111  0.338983
# ..        ...       ...       ...
# 464  0.285714  0.018519  0.000000
# 465  0.285714  0.018519  0.000000
# 466  0.000000  0.000000  0.067797
# 467  0.214286  0.018519  0.033898
# 468  0.285714  0.055556  0.067797
#
# [469 rows x 9 columns]

# %% [markdown]
# According to AHP analysis, we set weight of features.
# * Weight
#     - AREA = 0.198
#     - ESTATE = 0.327
#     - DISTANCE = 0.124
#     - POPULATION = 0.244
#     - SCHOOL = 0.02
#     - APARTMENT = 0.04
#     - MARKET = 0.048

# %%
# AHP
dfdf = scaled__df.copy()
dfdf['SCORE'] = dfdf['AREA']*0.198 - dfdf['ESTATE']*0.327 - dfdf['DIST_EASTDC']*0.0413 - dfdf['DIST_WESTDC']*0.0413 - dfdf['DIST_KOREADC']*0.0413 + dfdf['POP1000']*0.244 + dfdf['SCHOOL']*0.02 + dfdf['APART']*0.04 + dfdf['MARKET']*0.048

# %%
dfdf
# Out:
#          AREA    ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC   POP1000  \
# 0    0.043427  0.189831     0.318940     0.438800      0.443422  0.253190
# 1    0.169609  0.432974     0.341411     0.418207      0.436269  0.411800
# 2    0.166631  0.345562     0.346831     0.413507      0.424874  0.435364
# 3    0.250571  0.236987     0.349078     0.411788      0.450253  0.489771
# 4    0.117620  0.305306     0.395409     0.373522      0.403165  0.442966
# ..        ...       ...          ...          ...           ...       ...
# 464  0.346968  0.096093     0.443528     0.903896      0.970632  0.200805
# 465  0.421350  0.100464     0.427046     0.893226      0.953412  0.300610
# 466  0.050467  0.129816     0.387928     0.863363      0.910698  0.454400
# 467  0.197770  0.123122     0.402324     0.887401      0.930860  0.487522
# 468  0.137116  0.110148     0.335845     0.838629      0.858553  0.555611
#
#        SCHOOL     APART    MARKET     SCORE
# 0    0.357143  0.018519  0.983051  0.013764
# 1    0.642857  0.037037  0.101695 -0.037691
# 2    0.642857  0.018519  0.372881  0.008770
# 3    0.357143  0.037037  0.067797  0.053482
# 4    0.642857  0.111111  0.338983  0.016702
# ..        ...       ...       ...       ...
# 464  0.285714  0.018519  0.000000 -0.003007
# 465  0.285714  0.018519  0.000000  0.036476
# 466  0.000000  0.000000  0.067797 -0.007620
# 467  0.214286  0.018519  0.033898  0.032797
# 468  0.285714  0.055556  0.067797  0.053926
#
# [469 rows x 10 columns]

# %%
df['SCORE_CAT'] = pd.qcut(dfdf.SCORE ,4, labels=['매우부적합', '부적합', '적합', '매우적합'])
df
# Out:
#              GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0     현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1         선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2       현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3                  서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4           ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
# ..                   ...      ...    ...        ...         ...     ...
# 464  현대오일뱅크㈜직영 도봉현대셀프주유소      도봉구    도봉동  37.688374  127.045327  1366.0
# 465         GS칼텍스㈜ 도봉주유소      도봉구    도봉동  37.684369  127.045522  1640.7
# 466     (주)송만에너지 도봉제일주유소      도봉구    도봉동  37.674474  127.044067   271.0
# 467               노원교주유소      도봉구    도봉동  37.679015  127.049751   815.0
# 468                오복주유소      도봉구    방학동  37.662280  127.047441   591.0
#
#          ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0     8280000.0     8.970251    13.202286     11.678968     166    4465
# 1    18850000.0     9.568763    12.593357     11.494239     349    7404
# 2    15050000.0     9.713120    12.454393     11.199948     251    7069
# 3    10330000.0     9.772973    12.403577     11.855362     102    8374
# 4    13300000.0    11.006969    11.272070     10.639303     186    5401
# ..          ...          ...          ...           ...     ...     ...
# 464   4205000.0    12.288585    26.954691     25.294460      16    4651
# 465   4395000.0    11.849594    26.639204     24.849744     180    9341
# 466   5671000.0    10.807711    25.756175     23.746627     465    7251
# 467   5380000.0    11.191130    26.466958     24.267332      55    9057
# 468   4816000.0     9.420522    25.024822     22.399970     247    6762
#
#      POP1000  SCHOOL  APART  MARKET SCORE_CAT
# 0      15660       5      1      58       부적합
# 1      25467       9      2       6     매우부적합
# 2      26924       9      1      22       부적합
# 3      30288       5      2       4        적합
# 4      27394       9      6      20       부적합
# ..       ...     ...    ...     ...       ...
# 464    12421       4      1       0     매우부적합
# 465    18592       4      1       0       부적합
# 466    28101       0      0       4     매우부적합
# 467    30149       3      1       2       부적합
# 468    34359       4      3       4        적합
#
# [469 rows x 17 columns]

# %%
feature_cols = df.columns[[5,6,7,8,9,12,13,14,15]]
# define X and y
X = df[feature_cols]
y = df.SCORE_CAT

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1113)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (328, 9) (328,)
# (141, 9) (141,)

# %%
y_train.value_counts()
# Out:
# 부적합      87
# 적합       86
# 매우적합     82
# 매우부적합    73
# Name: SCORE_CAT, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier , AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
clf = DecisionTreeClassifier(random_state=0).fit(X_train, y_train)
predicted=clf.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
print ('Accuracy Score :',accuracy_score(y_test, predicted))
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[35  0  9  1]
#  [ 0 33  0  2]
#  [10  0 16  4]
#  [ 0  5  4 22]]
# Accuracy Score : 0.75177304964539
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.78      0.78      0.78        45
#         매우적합       0.87      0.94      0.90        35
#          부적합       0.55      0.53      0.54        30
#           적합       0.76      0.71      0.73        31
#
#     accuracy                           0.75       141
#    macro avg       0.74      0.74      0.74       141
# weighted avg       0.75      0.75      0.75       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , clf.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.210732
# ESTATE                  0.191658
# DIST_EASTDC             0.025755
# DIST_WESTDC             0.047889
# DIST_KOREADC            0.051467
# POP1000                 0.356623
# SCHOOL                  0.041029
# APART                   0.025217
# MARKET                  0.049629

# %%
lr = LogisticRegression(C=20, max_iter=1000, random_state=0).fit(X_train, y_train)
predicted=lr.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
print ('Accuracy Score :',accuracy_score(y_test, predicted))
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[31  1 12  1]
#  [ 0 29  3  3]
#  [ 0  3 21  6]
#  [ 1 12  5 13]]
# Accuracy Score : 0.6666666666666666
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.97      0.69      0.81        45
#         매우적합       0.64      0.83      0.73        35
#          부적합       0.51      0.70      0.59        30
#           적합       0.57      0.42      0.48        31
#
#     accuracy                           0.67       141
#    macro avg       0.67      0.66      0.65       141
# weighted avg       0.70      0.67      0.67       141

# %%
knn = KNeighborsClassifier().fit(X_train, y_train)
predicted=knn.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
print ('Accuracy Score :',accuracy_score(y_test, predicted))
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[20  8 12  5]
#  [ 8  9  3 15]
#  [ 6 10  9  5]
#  [ 6 12  6  7]]
# Accuracy Score : 0.3191489361702128
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.50      0.44      0.47        45
#         매우적합       0.23      0.26      0.24        35
#          부적합       0.30      0.30      0.30        30
#           적합       0.22      0.23      0.22        31
#
#     accuracy                           0.32       141
#    macro avg       0.31      0.31      0.31       141
# weighted avg       0.33      0.32      0.32       141

# %%
forest = RandomForestClassifier(random_state=0).fit(X_train, y_train)
predicted=forest.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
print ('Accuracy Score :',accuracy_score(y_test, predicted))
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[39  0  6  0]
#  [ 0 31  2  2]
#  [ 4  0 18  8]
#  [ 2  7  3 19]]
# Accuracy Score : 0.7588652482269503
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.87      0.87      0.87        45
#         매우적합       0.82      0.89      0.85        35
#          부적합       0.62      0.60      0.61        30
#           적합       0.66      0.61      0.63        31
#
#     accuracy                           0.76       141
#    macro avg       0.74      0.74      0.74       141
# weighted avg       0.76      0.76      0.76       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , forest.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.136471
# ESTATE                  0.157177
# DIST_EASTDC             0.084052
# DIST_WESTDC             0.073153
# DIST_KOREADC            0.091833
# POP1000                 0.303613
# SCHOOL                  0.041556
# APART                   0.068159
# MARKET                  0.043985

# %%
gb = GradientBoostingClassifier(random_state=0).fit(X_train, y_train)
predicted=gb.predict(X_test)
print ('Confusion Matrix :')
print(confusion_matrix(y_test, predicted))
print ('Accuracy Score :',accuracy_score(y_test, predicted))
print ('Report : ')
print (classification_report(y_test, predicted))
# Out:
# Confusion Matrix :
# [[37  0  8  0]
#  [ 0 27  1  7]
#  [ 6  0 16  8]
#  [ 1  3  5 22]]
# Accuracy Score : 0.723404255319149
# Report :
#               precision    recall  f1-score   support
#
#        매우부적합       0.84      0.82      0.83        45
#         매우적합       0.90      0.77      0.83        35
#          부적합       0.53      0.53      0.53        30
#           적합       0.59      0.71      0.65        31
#
#     accuracy                           0.72       141
#    macro avg       0.72      0.71      0.71       141
# weighted avg       0.74      0.72      0.73       141

# %%
pd.DataFrame([(i, j) for i, j in zip(feature_cols , gb.feature_importances_)]).rename(columns={0:'Feature Name',1:'Feature Importance'}).set_index('Feature Name')
# Out:
#               Feature Importance
# Feature Name
# AREA                    0.145299
# ESTATE                  0.203261
# DIST_EASTDC             0.052151
# DIST_WESTDC             0.041178
# DIST_KOREADC            0.042855
# POP1000                 0.448643
# SCHOOL                  0.039359
# APART                   0.013293
# MARKET                  0.013961

# %%
## adaboost나 xgboost나 LGbm하고 싶은데 잘 모르겠음 다중분류라 파라미터 뜯어볼 시간이 없어서 안함.

# %% [markdown]
# ## 찬이 인공신경망 들어가야 할 부분

# %% [markdown]
# 일부러 에러나라고 쓸겡
# y 형식이 아마 int여야하는걸루 알아
# 매우부적합 = 0 부적합 = 1 적합 = 2 매우적합 = 3 이런식으로 이거 먼저 df에 컬럼추가 해주고 그담에 y = df.~~~ 이부분 작성하면 될듯
# 내가 찾은바로는 label encoding 하면 sparse_categorical_crossentropy가 맞대

# %%
df['SCORE_CAT']
# Out:
# 0        부적합
# 1      매우부적합
# 2        부적합
# 3         적합
# 4        부적합
#        ...
# 464    매우부적합
# 465      부적합
# 466    매우부적합
# 467      부적합
# 468       적합
# Name: SCORE_CAT, Length: 469, dtype: category
# Categories (4, object): ['매우부적합' < '부적합' < '적합' < '매우적합']

# %%
# 라벨 인코딩
# 1대1 매칭시켜도 되는데
# 수업 컨텐츠 사용할려고
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['SCORE_CAT'])
label_encoded = le.transform(df['SCORE_CAT'])


label_df = pd.DataFrame(label_encoded, 
                       columns = ['Score_label'])

label_df.head()
# Out:
#    Score_label
# 0            2
# 1            0
# 2            2
# 3            3
# 4            2

# %%
# 매우부적합 : 0
# 부적합 : 2
# 적합 : 3
# 매우적합 : 1
df_ann = pd.concat([df, label_df], axis =  1)
df_ann.head()
# Out:
#           GAS_STATION DISTRICT   DONG   LATITUDE   LONGITUDE    AREA  \
# 0  현대오일뱅크(주) 직영소월길주유소      용산구    후암동  37.554409  126.977735   245.0
# 1      선익상사(주) 동자동주유소      용산구    동자동  37.550201  126.972418   711.0
# 2    현대오일뱅크㈜ 직영갈월동주유소      용산구    갈월동  37.547029  126.972228   700.0
# 3               서계주유소      용산구    서계동  37.552366  126.968994  1010.0
# 4        ㈜영원에너지 풍기주유소      용산구  원효로2가  37.535589  126.962709   519.0
#
#        ESTATE  DIST_EASTDC  DIST_WESTDC  DIST_KOREADC  POP100  POP500  \
# 0   8280000.0     8.970251    13.202286     11.678968     166    4465
# 1  18850000.0     9.568763    12.593357     11.494239     349    7404
# 2  15050000.0     9.713120    12.454393     11.199948     251    7069
# 3  10330000.0     9.772973    12.403577     11.855362     102    8374
# 4  13300000.0    11.006969    11.272070     10.639303     186    5401
#
#    POP1000  SCHOOL  APART  MARKET SCORE_CAT  Score_label
# 0    15660       5      1      58       부적합            2
# 1    25467       9      2       6     매우부적합            0
# 2    26924       9      1      22       부적합            2
# 3    30288       5      2       4        적합            3
# 4    27394       9      6      20       부적합            2

# %%
# 컬럼 필터링
feature_cols = df_ann.columns[[5,6,7,8,9,12,13,14,15]]
# define X and y
X = df_ann[feature_cols]
y = df_ann['Score_label']

# %%
# (x_train, y_train), (x_test, y_test) 데이터 나누기
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1113)

# %%
# 데이터 정규화해서 스케일 낮추기
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# train 데이터 분리 (train/valid)
train_scaled, val_scaled, train_target, val_target = train_test_split(X_train_scaled, y_train, test_size=0.3, random_state=1113)

# %%
# dense 조합 바꿔가면서 보기
neural_model = Sequential()

neural_model.add(Dense(64, activation = 'relu', input_shape = (9, )))
neural_model.add(Dense(32, activation = 'relu'))
neural_model.add(Dense(8, activation = 'relu'))
neural_model.add(Dense(4, activation = 'softmax'))


neural_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['sparse_categorical_accuracy']) 
neural_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dense_10 (Dense)            (None, 8)                 264
#
#  dense_11 (Dense)            (None, 4)                 36
#
# =================================================================
# Total params: 3,020
# Trainable params: 3,020
# Non-trainable params: 0
# _________________________________________________________________

# %%
result = neural_model.fit(train_scaled, train_target, epochs = 1000, validation_data = (val_scaled, val_target),
                         callbacks = [EarlyStopping(monitor = 'val_loss', patience=10, verbose = 1),
                                     ReduceLROnPlateau(monitor = 'val_loss', patience = 10, factor = 0.1, min_lr=0.0001, verbose = 1)])


result_df = pd.DataFrame(result.history)
result_df['score'] = result_df.index+1
result_df.set_index('score', inplace = True)
result_df
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 2s 75ms/step - loss: 1.3983 - sparse_categorical_accuracy: 0.1703 - val_loss: 1.3800 - val_sparse_categorical_accuracy: 0.3535 - lr: 0.0010
# Epoch 2/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3800 - sparse_categorical_accuracy: 0.2882 - val_loss: 1.3788 - val_sparse_categorical_accuracy: 0.2828 - lr: 0.0010
# Epoch 3/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 1.3700 - sparse_categorical_accuracy: 0.3406 - val_loss: 1.3748 - val_sparse_categorical_accuracy: 0.2828 - lr: 0.0010
# Epoch 4/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 1.3629 - sparse_categorical_accuracy: 0.4105 - val_loss: 1.3705 - val_sparse_categorical_accuracy: 0.3434 - lr: 0.0010
# Epoch 5/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 1.3548 - sparse_categorical_accuracy: 0.4541 - val_loss: 1.3653 - val_sparse_categorical_accuracy: 0.3838 - lr: 0.0010
# Epoch 6/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3450 - sparse_categorical_accuracy: 0.4891 - val_loss: 1.3562 - val_sparse_categorical_accuracy: 0.4141 - lr: 0.0010
# Epoch 7/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 1.3353 - sparse_categorical_accuracy: 0.4847 - val_loss: 1.3440 - val_sparse_categorical_accuracy: 0.4242 - lr: 0.0010
# Epoch 8/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3215 - sparse_categorical_accuracy: 0.5066 - val_loss: 1.3403 - val_sparse_categorical_accuracy: 0.4040 - lr: 0.0010
# Epoch 9/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 1.3104 - sparse_categorical_accuracy: 0.5022 - val_loss: 1.3263 - val_sparse_categorical_accuracy: 0.3939 - lr: 0.0010
# Epoch 10/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 1.2895 - sparse_categorical_accuracy: 0.5371 - val_loss: 1.2975 - val_sparse_categorical_accuracy: 0.4949 - lr: 0.0010
# Epoch 11/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 1.2666 - sparse_categorical_accuracy: 0.5328 - val_loss: 1.2687 - val_sparse_categorical_accuracy: 0.5051 - lr: 0.0010
# Epoch 12/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 1.2437 - sparse_categorical_accuracy: 0.5590 - val_loss: 1.2505 - val_sparse_categorical_accuracy: 0.5657 - lr: 0.0010
# Epoch 13/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 1.2116 - sparse_categorical_accuracy: 0.5895 - val_loss: 1.2124 - val_sparse_categorical_accuracy: 0.5455 - lr: 0.0010
# Epoch 14/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 1.1834 - sparse_categorical_accuracy: 0.5546 - val_loss: 1.1800 - val_sparse_categorical_accuracy: 0.5556 - lr: 0.0010
# Epoch 15/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 1.1450 - sparse_categorical_accuracy: 0.5590 - val_loss: 1.1541 - val_sparse_categorical_accuracy: 0.5152 - lr: 0.0010
# Epoch 16/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 1.1068 - sparse_categorical_accuracy: 0.5852 - val_loss: 1.1176 - val_sparse_categorical_accuracy: 0.5253 - lr: 0.0010
# Epoch 17/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0701 - sparse_categorical_accuracy: 0.6201 - val_loss: 1.0708 - val_sparse_categorical_accuracy: 0.5657 - lr: 0.0010
# Epoch 18/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0254 - sparse_categorical_accuracy: 0.6245 - val_loss: 1.0250 - val_sparse_categorical_accuracy: 0.5758 - lr: 0.0010
# Epoch 19/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.9787 - sparse_categorical_accuracy: 0.5983 - val_loss: 0.9936 - val_sparse_categorical_accuracy: 0.5556 - lr: 0.0010
# Epoch 20/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.9365 - sparse_categorical_accuracy: 0.6507 - val_loss: 0.9619 - val_sparse_categorical_accuracy: 0.6364 - lr: 0.0010
# Epoch 21/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.8920 - sparse_categorical_accuracy: 0.7118 - val_loss: 0.8997 - val_sparse_categorical_accuracy: 0.6970 - lr: 0.0010
# Epoch 22/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.8437 - sparse_categorical_accuracy: 0.7424 - val_loss: 0.8524 - val_sparse_categorical_accuracy: 0.7071 - lr: 0.0010
# Epoch 23/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.8032 - sparse_categorical_accuracy: 0.7074 - val_loss: 0.8189 - val_sparse_categorical_accuracy: 0.7475 - lr: 0.0010
# Epoch 24/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7720 - sparse_categorical_accuracy: 0.7598 - val_loss: 0.7765 - val_sparse_categorical_accuracy: 0.7778 - lr: 0.0010
# Epoch 25/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7407 - sparse_categorical_accuracy: 0.7686 - val_loss: 0.7509 - val_sparse_categorical_accuracy: 0.7778 - lr: 0.0010
# Epoch 26/1000
# 8/8 [==============================] - 0s 31ms/step - loss: 0.7094 - sparse_categorical_accuracy: 0.7817 - val_loss: 0.7063 - val_sparse_categorical_accuracy: 0.8283 - lr: 0.0010
# Epoch 27/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6931 - sparse_categorical_accuracy: 0.7555 - val_loss: 0.6850 - val_sparse_categorical_accuracy: 0.8283 - lr: 0.0010
# Epoch 28/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6477 - sparse_categorical_accuracy: 0.8122 - val_loss: 0.6763 - val_sparse_categorical_accuracy: 0.7879 - lr: 0.0010
# Epoch 29/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6179 - sparse_categorical_accuracy: 0.8297 - val_loss: 0.6362 - val_sparse_categorical_accuracy: 0.8485 - lr: 0.0010
# Epoch 30/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5952 - sparse_categorical_accuracy: 0.8166 - val_loss: 0.6135 - val_sparse_categorical_accuracy: 0.8586 - lr: 0.0010
# Epoch 31/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5695 - sparse_categorical_accuracy: 0.8472 - val_loss: 0.5838 - val_sparse_categorical_accuracy: 0.8687 - lr: 0.0010
# Epoch 32/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5481 - sparse_categorical_accuracy: 0.8428 - val_loss: 0.5744 - val_sparse_categorical_accuracy: 0.8384 - lr: 0.0010
# Epoch 33/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5248 - sparse_categorical_accuracy: 0.8734 - val_loss: 0.5376 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 34/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5184 - sparse_categorical_accuracy: 0.8384 - val_loss: 0.5213 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 35/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.4899 - sparse_categorical_accuracy: 0.8734 - val_loss: 0.5197 - val_sparse_categorical_accuracy: 0.8687 - lr: 0.0010
# Epoch 36/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4817 - sparse_categorical_accuracy: 0.8515 - val_loss: 0.5202 - val_sparse_categorical_accuracy: 0.8182 - lr: 0.0010
# Epoch 37/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4803 - sparse_categorical_accuracy: 0.8646 - val_loss: 0.4686 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 38/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4549 - sparse_categorical_accuracy: 0.8559 - val_loss: 0.4600 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 39/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4339 - sparse_categorical_accuracy: 0.8996 - val_loss: 0.4614 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 40/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4219 - sparse_categorical_accuracy: 0.8777 - val_loss: 0.4473 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 41/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4062 - sparse_categorical_accuracy: 0.8865 - val_loss: 0.4353 - val_sparse_categorical_accuracy: 0.8889 - lr: 0.0010
# Epoch 42/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3955 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.4122 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 43/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3830 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.4131 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 44/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3868 - sparse_categorical_accuracy: 0.8734 - val_loss: 0.3973 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 45/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3600 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.3765 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 46/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3506 - sparse_categorical_accuracy: 0.9127 - val_loss: 0.3822 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 47/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3651 - sparse_categorical_accuracy: 0.8777 - val_loss: 0.3624 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 48/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3434 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.3718 - val_sparse_categorical_accuracy: 0.8990 - lr: 0.0010
# Epoch 49/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3332 - sparse_categorical_accuracy: 0.9214 - val_loss: 0.3572 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 50/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.3194 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.3389 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 51/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3091 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.3334 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 52/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3092 - sparse_categorical_accuracy: 0.8996 - val_loss: 0.3362 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 53/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.2944 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.3150 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 54/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.3035 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.3099 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 55/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2928 - sparse_categorical_accuracy: 0.9214 - val_loss: 0.3001 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 56/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2718 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.3061 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 57/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2847 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.3010 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 58/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2629 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2887 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 59/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2601 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.2802 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 60/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2616 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.2756 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 61/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2602 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.2876 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 62/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2439 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.2662 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 63/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2435 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2680 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 64/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2469 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.2554 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 65/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2335 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.2511 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 66/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2262 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.2530 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 67/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2238 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2540 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 68/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2163 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2429 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 69/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2151 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.2385 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 70/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 0.2282 - sparse_categorical_accuracy: 0.9214 - val_loss: 0.2363 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 71/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 0.2042 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2368 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 72/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2088 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2362 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 73/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 0.2039 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2255 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 74/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 0.1986 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2243 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 75/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2004 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.2429 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 76/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2078 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.2285 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 77/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2190 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.2338 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 78/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1887 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.2132 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 79/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1827 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.2233 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 80/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1850 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.2172 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 81/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1813 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2158 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 82/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1797 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.2118 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 83/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1728 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.2124 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 84/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1746 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2071 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 85/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1669 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.1993 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 86/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1674 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2075 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 87/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1642 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2013 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 88/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1634 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1991 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 89/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1614 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.2220 - val_sparse_categorical_accuracy: 0.9091 - lr: 0.0010
# Epoch 90/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1863 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.2051 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 91/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1773 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.2127 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 92/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1649 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.1914 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 93/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1552 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.1916 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 94/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1535 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1896 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 95/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1486 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1881 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 96/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1495 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1893 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 97/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1516 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1816 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 98/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1421 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1789 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 99/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1864 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 100/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1413 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1763 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 101/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1396 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1799 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 102/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1388 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.1745 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 103/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.1424 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1756 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 104/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1362 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.1722 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 105/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1342 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1717 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 106/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1318 - sparse_categorical_accuracy: 0.9651 - val_loss: 0.1644 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 107/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1344 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1740 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 108/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1356 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.1651 - val_sparse_categorical_accuracy: 0.9596 - lr: 0.0010
# Epoch 109/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1324 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1653 - val_sparse_categorical_accuracy: 0.9394 - lr: 0.0010
# Epoch 110/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1365 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.1839 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 111/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1697 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 112/1000
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9607 - val_loss: 0.1876 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 113/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1366 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1686 - val_sparse_categorical_accuracy: 0.9293 - lr: 0.0010
# Epoch 114/1000
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1370 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1715 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 115/1000
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1403 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.1915 - val_sparse_categorical_accuracy: 0.9192 - lr: 0.0010
# Epoch 116/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1408 - sparse_categorical_accuracy: 0.9688
# Epoch 116: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1377 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.1689 - val_sparse_categorical_accuracy: 0.9495 - lr: 0.0010
# Epoch 116: early stopping
#            loss  sparse_categorical_accuracy  val_loss  \
# score
# 1      1.398276                     0.170306  1.380007
# 2      1.379986                     0.288210  1.378809
# 3      1.369973                     0.340611  1.374841
# 4      1.362858                     0.410480  1.370507
# 5      1.354822                     0.454148  1.365328
# ...         ...                          ...       ...
# 112    0.128434                     0.960699  0.187554
# 113    0.136576                     0.969432  0.168596
# 114    0.136986                     0.956332  0.171474
# 115    0.140271                     0.947598  0.191486
# 116    0.137728                     0.956332  0.168864
#
#        val_sparse_categorical_accuracy     lr
# score
# 1                             0.353535  0.001
# 2                             0.282828  0.001
# 3                             0.282828  0.001
# 4                             0.343434  0.001
# 5                             0.383838  0.001
# ...                                ...    ...
# 112                           0.919192  0.001
# 113                           0.929293  0.001
# 114                           0.949495  0.001
# 115                           0.919192  0.001
# 116                           0.949495  0.001
#
# [116 rows x 5 columns]

# %%
# 손실률(loss) /  절대오차(mean absolute error)에 대한 그래프 설정
plt.rcParams['font.family'] = 'Gulim'
plt.rcParams['font.size'] = 15
plt.rcParams['axes.unicode_minus'] = False

# 그래프 그리기 위한 객체 생성
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 5), dpi = 150)

# 1) 훈련 및 검증 손실 plotting
sns.lineplot(data = result_df, x = result_df.index, y = 'loss', color = 'darkblue', label = 'train 손실률', ax = ax1)
sns.lineplot(data = result_df, x = result_df.index, y = 'val_loss', color = 'orange', label = 'valid 손실률', ax = ax1)
ax1.set_title('훈련 및 검증 손실률')
ax1.set_xlabel('반복회차(Epoch)')
ax1.set_ylabel('손실률(Loss)')
ax1.grid()
ax1.legend()

# 2) 훈련 및 검증 절대오차 plotting
sns.lineplot(data = result_df, x = result_df.index, y = 'sparse_categorical_accuracy', color = 'darkblue', label = 'train accuracy', ax = ax2)
sns.lineplot(data = result_df, x = result_df.index, y = 'val_sparse_categorical_accuracy', color = 'orange', label = 'test val_accuracy', ax = ax2)
ax2.set_title('훈련 및 검증 accuracy')
ax2.set_xlabel('반복회차(Epoch)')
ax2.set_ylabel('accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
let_evaluate = neural_model.evaluate(X_test_scaled, y_test)
print('최종 손실률 : %f, 최종 accuracy : %f' % (let_evaluate[0], let_evaluate[1]))
# Out:
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9645
# 최종 손실률 : 0.136446, 최종 accuracy : 0.964539

# %% [markdown]
# ## 부록

# %%
import folium as g

# %%
# 서울 시 내 MFC 장소로 적합한 주유소 위치후보.
seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(df[df['SCORE_CAT'] == '적합'])):
    marker = g.Marker([df[df['SCORE_CAT'] == '적합']['LATITUDE'].iloc[i], df[df['SCORE_CAT'] == '적합']['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'))
    marker.add_to(seoul_map)

seoul_map

# %%
# groupby 집계함수로 구별로 max값 추출한 뒤 클러스터링 결과와 결합하여 구당 하나의 최적 위치 설정.
optdf = df.groupby('DISTRICT').max().loc[['동대문구', '양천구', '동작구', '송파구', '구로구', '서대문구', '영등포구']].reset_index()
optdf

# %%
# 서울 시 내 입지순위 1위 지역 MFC 장소로 적합한 주유소 위치. 지도 시각화, 기호 누르면 해당 주유소의 이름과 위경도 추출해줌.
seoul_map = g.Map(location=[37.541, 126.986], tiles='OpenStreetMap', zoom_start=11.5) # 37.541, 126.986 <- Latitude & Longitude of Seoul
for i in range(len(optdf)):
    name = optdf.iloc[i, 1]
    lat = optdf.iloc[i, 3]
    long = optdf.iloc[i, 4]
    popup = g.Popup('<b>'+name+'</b><br>' + 'Latitude : ' + str(lat) + '<br>Longitude : '+ str(long), max_width=300)
    marker = g.Marker([optdf['LATITUDE'].iloc[i], optdf['LONGITUDE'].iloc[i]], icon=g.Icon(color='red'), popup=popup)
    marker.add_to(seoul_map)

seoul_map

# %% [markdown]
# ## 신경망

# %% [markdown]
# df.head()

# %% [markdown]
# df['LOCATION'].value_counts()

# %% [markdown]
# train_scaled, val_scaled, train_target, val_target = train_test_split(X_train_scaled, y_train, test_size=0.3, random_state=42)

# %% [markdown]
# # dense 조합 바꿔가면서 보기
# neural_model = Sequential()
#
# neural_model.add(Dense(64, activation = 'relu', input_shape = (9, )))
# neural_model.add(Dense(32, activation = 'relu'))
# neural_model.add(Dense(8, activation = 'relu'))
# neural_model.add(Dense(1, activation = 'sigmoid'))
#
#
# neural_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# neural_model.summary()

# %% [markdown]
# result = neural_model.fit(train_scaled, train_target, epochs = 1000, validation_data = (val_scaled, val_target),
#                          callbacks = [EarlyStopping(monitor = 'val_loss', patience=10, verbose = 1),
#                                      ReduceLROnPlateau(monitor = 'val_loss', patience = 10, factor = 0.1, min_lr=0.0001, verbose = 1)])
#
#
# result_df = pd.DataFrame(result.history)
# result_df['score'] = result_df.index+1
# result_df.set_index('score', inplace = True)
# result_df

# %% [markdown]
# # 손실률(loss) /  절대오차(mean absolute error)에 대한 그래프 설정
# plt.rcParams['font.family'] = 'Gulim'
# plt.rcParams['font.size'] = 15
# plt.rcParams['axes.unicode_minus'] = False
#
# # 그래프 그리기 위한 객체 생성
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 5), dpi = 150)
#
# # 1) 훈련 및 검증 손실 plotting
# sns.lineplot(data = result_df, x = result_df.index, y = 'loss', color = 'darkblue', label = 'train 손실률', ax = ax1)
# sns.lineplot(data = result_df, x = result_df.index, y = 'val_loss', color = 'orange', label = 'test 손실률', ax = ax1)
# ax1.set_title('훈련 및 검증 손실률')
# ax1.set_xlabel('반복회차')
# ax1.set_ylabel('손실률(Loss)')
# ax1.grid()
# ax1.legend()
#
# # 2) 훈련 및 검증 절대오차 plotting
# sns.lineplot(data = result_df, x = result_df.index, y = 'accuracy', color = 'darkblue', label = 'train accuracy', ax = ax2)
# sns.lineplot(data = result_df, x = result_df.index, y = 'val_accuracy', color = 'orange', label = 'test val_accuracy', ax = ax2)
# ax2.set_title('훈련 및 검증 accuracy')
# ax2.set_xlabel('반복회차')
# ax2.set_ylabel('accuracy')
# ax2.grid()
# ax2.legend()
#
# plt.show()

# %% [markdown]
# let_evaluate = neural_model.evaluate(X_test_scaled, y_test)
# print('최종 손실률 : %f, 최종 accuracy : %f' % (let_evaluate[0], let_evaluate[1]))

# %% [markdown]
# test_prediction = neural_model.predict(X_test_scaled)
# neural_network_predict_value_df = pd.DataFrame(data = test_prediction, columns = ['predict_value'])
# neural_network_predict_value_df

# %% [markdown]
# y_test.value_counts()

# %% [markdown]
# neural_network_predict_value_df.value_counts()
